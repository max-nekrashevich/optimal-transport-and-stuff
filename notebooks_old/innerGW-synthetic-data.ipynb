# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

# %%
from copy import deepcopy

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as o
import geotorch


DEVICE = None
# DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

from src.distributions import *
from src.loggers import TensorBoardLogger, WandbLogger
from src.train import train


tb_logger = TensorBoardLogger()
wandb_logger = WandbLogger(project="optimal-transport", entity="_devourer_")

# %%
class SqOT:
    def __init__(self, l=.05, p=2):
        self.l = l
        self.p = p

    def __call__(self, x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
        return self.l * torch.norm(x - y, self.p, dim=1) ** self.p


class InnerGW:
    def __init__(self, l=.05):
        self.l = l

    def __call__(self, x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
        P = torch.einsum("ij,ik->jk", y, x)
        P = P / torch.norm(P)
        return self.l * torch.norm(x @ P.T - y, 2, dim=1) ** 2


class SqGW:
    def __init__(self, l=.05, alpha=1.):
        self.l = l
        self.alpha = alpha

    # def __call__(self, x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
    #     P = self._get_P(x, y)
    #     return self.l * (torch.norm(x @ P - y, 2, dim=1) ** 2 +
    #                 self.alpha * (torch.norm(x, 2, dim=1) ** 2 - 
    #                          torch.norm(y, 2, dim=1) ** 2) ** 2)

    def __call__(self, x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
        P = torch.einsum("ij,ik->jk", y, x)
        P = P / torch.norm(P)
        return self.l * (torch.norm(x @ P.T - y, 2, dim=1) ** 2 -
                         self.alpha * (torch.norm(x, 2, dim=1) ** 2 *
                                       torch.norm(y, 2, dim=1) ** 2))


class SqGW_opt:
    def __init__(self, p, q, l=.05, alpha=1.,
                 n_iter=10,
                 optimizer=o.Adam,
                 optimizer_params=dict(lr=5e-5, betas=(.0, .9)),
                 logger=None):
        self.P = nn.Linear(p, q, bias=False)
        geotorch.sphere(self.P, "weight")
        self.P_opt = optimizer(self.P.parameters(), **optimizer_params)

        self.l = l
        self.alpha = alpha
        self.n_iter = n_iter

        self.logger = logger
        self.step = 0

    def __call__(self, x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
        for _ in range(self.n_iter):
            self.P_opt.zero_grad()
            Px = self.P(x)
            cost = self.l * (torch.norm(Px - y.detach(), 2, dim=1) ** 2)
            cost.mean().backward()
            self.P_opt.step()
        Px = self.P(x)
        if self.logger:
            with torch.no_grad():
                target_P = torch.einsum("ij,ik->jk", y, x)
                target_P = target_P / torch.norm(target_P)
                self.logger.log("P MSE", F.mse_loss(self.P.weight, target_P).item(), 1 + self.step // 15)
            self.step += 1
        return self.l * (torch.norm(Px - y, 2, dim=1) ** 2 -
                         self.alpha * (torch.norm(x, 2, dim=1) ** 2 * 
                                       torch.norm(y, 2, dim=1) ** 2))

# %% [markdown]
# ### Define architecture

# %%
p, q = 2, 2
n_neurons = 32

critic = nn.Sequential(
    nn.Linear(q, n_neurons), nn.LeakyReLU(),
    nn.Linear(n_neurons, n_neurons), nn.LeakyReLU(),
    nn.Linear(n_neurons, n_neurons), nn.LeakyReLU(),
    nn.Linear(n_neurons, 1), nn.Tanh()
)

mover = nn.Sequential(
    nn.Linear(p, n_neurons), nn.LeakyReLU(),
    nn.Linear(n_neurons, n_neurons), nn.LeakyReLU(),
    nn.Linear(n_neurons, n_neurons), nn.LeakyReLU(),
    nn.Linear(n_neurons, q)
)

# %%
def run_experiment(source, target, cost, n_iter, *,
                   logger=None, **kwargs):
    if logger: logger.start()
    mover_copy = deepcopy(mover)
    critic_copy = deepcopy(critic)
    try:
        train(source, target, mover_copy, critic_copy, cost,
              n_iter=n_iter,
              logger=logger,
              **kwargs)
    except KeyboardInterrupt:
        pass
    finally:
        if logger: logger.finish()
    return mover_copy, critic_copy

# %% [markdown]
# ## GMM to GMM

# %%
source = GaussianMixture(2 * torch.tensor([[ 3.,  0.], [ 0.,  3.], [-3.,  0.], [ 0., -3.],
                                           [ 2.,  2.], [ 2., -2.], [-2.,  2.], [-2., -2.]]),
                                          .2 * torch.ones(8, 2))
target = GaussianMixture(torch.tensor([[ 3.,  0.], [ 0.,  3.], [-3.,  0.], [ 0., -3.],
                                       [ 2.,  2.], [ 2., -2.], [-2.,  2.], [-2., -2.]]),
                                      .2 * torch.ones(8, 2))

# %% [markdown]
# ### Regular OT

# %%
run_experiment(
    source, target,
    n_samples=32,
    n_iter=250,
    cost=SqOT(),
    # logger=wandb_logger
);
# Out:
# Output()
#   0%|          | 0/250 [00:00<?, ?it/s]

# %% [markdown]
# ### innerGW

# %%
run_experiment(
    source, target,
    n_iter=20000,
    cost=InnerGW(l=.5),
    plotter=SimplePlotter(source_lims=None, target_lims=None),
    # plotter=SimplePlotter(source_lims=((-8, 8), (-8, 8)),
    #                 target_lims=((-4, 4), (-4, 4)),
    #                 show_progress=False
    #                ),
    # logger=wandb_logger
    n_inner_iter=5
)
# 14
# Out:
# Output()
#   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
run_experiment(
    source, target,
    cost=SqGW_opt(p, q, alpha=0., logger=wandb_logger),
    n_iter=5000,
    plotter=SimplePlotter(source_lims=((-8, 8), (-8, 8)),
                    target_lims=((-4, 4), (-4, 4)),
                    show_progress=False
                   ),
    logger=wandb_logger
)

# %% [markdown]
# ### sqGW

# %%
run_experiment(
    source, target,
    cost=SqGW(alpha=.01,),
    n_iter=5000,
    plotter=SimplePlotter(source_lims=((-8, 8), (-8, 8)),
                    target_lims=((-4, 4), (-4, 4)),
                    # show_progress=False
                   ),
    # logger=wandb_logger
)

# %% [markdown]
# ## Normal to Normal

# %%
source = Normal(torch.tensor([3., 0.]), torch.tensor([1.,2.]))
target = Normal(torch.tensor([-3., 0.]), torch.tensor([1.,2.]))

# %% [markdown]
# ### Regular OT

# %%
run_experiment(
    source, target,
    n_iter=2500,
    cost=SqOT(),
    plotter=SimplePlotter(source_lims=((-6, 6), (-6, 6)),
                    target_lims=((-6, 6), (-6, 6)),
                    show_progress=False),
    logger=wandb_logger
)

# %% [markdown]
# ### innerGW

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=InnerGW(),
    plotter=SimplePlotter(source_lims=((-6, 6), (-6, 6)),
                    target_lims=((-6, 6), (-6, 6)),
                    show_progress=False),
    logger=wandb_logger
)

# %%
run_experiment(
    source, target,
    cost=SqGW_opt(2, 2, alpha=0., logger=wandb_logger),
    n_iter=5000,
    plotter=SimplePlotter(source_lims=((-8, 8), (-8, 8)),
                    target_lims=((-4, 4), (-4, 4)),
                    show_progress=False
                   ),
    logger=wandb_logger
)

# %% [markdown]
# ### sqGW

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=SqGW(alpha=.01),
    plotter=SimplePlotter(source_lims=((-6, 6), (-6, 6)),
                    target_lims=((-6, 6), (-6, 6)),
                    show_progress=False),
    logger=wandb_logger
)

# %% [markdown]
# ## Moon to Moon

# %%
source = MoonsDistribution(upper=True, sigma=.1)
target = MoonsDistribution(upper=False, sigma=.1)

# %% [markdown]
# ### Regular OT

# %%
run_experiment(
    source, target,
    n_iter=2500,
    cost=SqOT(),
    plotter=SimplePlotter(source_lims=None,
                    target_lims=None,
                    show_progress=False,
                    ),
    logger=wandb_logger
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: _devourer_ (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/_devourer_/optimal-transport/runs/35qoddcq" target="_blank">scarlet-firebrand-46</a></strong> to <a href="https://wandb.ai/_devourer_/optimal-transport" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#   0%|          | 0/2500 [00:00<?, ?it/s]
# <br/>Waiting for W&B process to finish, PID 6569... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 1.19MB of 1.19MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>cost</td><td>▄▃▂▂▁▁▁▁▁▁▂▂▂▂▃▃▄▄▅▆▇▇▇▇▇▇▇▇▇████▇███▇▇█</td></tr><tr><td>loss</td><td>▄▃▂▁▁▁▂▂▃▃▄▅▅▅▆▆▇▇▇▇▇▇▇▇█▇██████████████</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>cost</td><td>0.08915</td></tr><tr><td>loss</td><td>0.08881</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 8 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">scarlet-firebrand-46</strong>: <a href="https://wandb.ai/_devourer_/optimal-transport/runs/35qoddcq" target="_blank">https://wandb.ai/_devourer_/optimal-transport/runs/35qoddcq</a><br/>
# Find logs at: <code>./wandb/run-20220205_093840-35qoddcq/logs</code><br/>

# %% [markdown]
# ### innerGW

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=InnerGW(),
    plotter=SimplePlotter(source_lims=None,
                    target_lims=None,
                    show_progress=False
                   ),
    logger=wandb_logger,
    n_inner_iter=2,
    log_plot_interval=50
)

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=SqGW_opt(2, 2, alpha=0., logger=wandb_logger),
    plotter=SimplePlotter(source_lims=None,
                    target_lims=None,
                    show_progress=False
                   ),
    logger=wandb_logger,
    n_inner_iter=2,
)

# %% [markdown]
# ## Normal to "57"

# %%
source = Normal(torch.tensor([0., 0.]), torch.tensor([1.,2.]))

image = plt.imread("../../data/fifty-seven.png")[:, :, 3]
target = ImageDistribution(torch.from_numpy(image), 2., n_components=20000)

# %% [markdown]
# ### Regular OT

# %%
run_experiment(
    source, target,
    n_iter=2500,
    cost=SqOT(),
    plotter=SimplePlotter(source_lims=((-4, 4), (-4, 4)),
                    target_lims=((-4, 4), (-4, 4)),
                    show_progress=False),
    logger=wandb_logger
)
# Out:
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/_devourer_/optimal-transport/runs/1mrd8s4e" target="_blank">fancy-gorge-47</a></strong> to <a href="https://wandb.ai/_devourer_/optimal-transport" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#   0%|          | 0/2500 [00:00<?, ?it/s]
# <br/>Waiting for W&B process to finish, PID 6713... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 2.23MB of 2.23MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>cost</td><td>█▄▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▄▃▃</td></tr><tr><td>loss</td><td>█▄▁▁▂▂▂▂▂▃▂▃▃▃▃▃▂▂▃▃▃▃▃▃▄▃▄▃▃▃▃▃▃▃▃▃▃▄▃▃</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>cost</td><td>0.05046</td></tr><tr><td>loss</td><td>0.05972</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 27 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fancy-gorge-47</strong>: <a href="https://wandb.ai/_devourer_/optimal-transport/runs/1mrd8s4e" target="_blank">https://wandb.ai/_devourer_/optimal-transport/runs/1mrd8s4e</a><br/>
# Find logs at: <code>./wandb/run-20220205_094055-1mrd8s4e/logs</code><br/>

# %% [markdown]
# ### innerGW

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=InnerGW(),
    plotter=SimplePlotter(source_lims=((-4, 4), (-4, 4)),
                    target_lims=((-4, 4), (-4, 4)),
                    show_progress=False),
    logger=wandb_logger
)
# Out:
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/_devourer_/optimal-transport/runs/3m8uepei" target="_blank">wandering-bee-48</a></strong> to <a href="https://wandb.ai/_devourer_/optimal-transport" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <br/>Waiting for W&B process to finish, PID 7158... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 5.43MB of 5.43MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>cost</td><td>█▁▂▃▃▄▄▃▃▃▄▄▄▄▄▅▄▄▄▅▅▄▄▄▅▅▅▄▅▄▅▅▅▅▄▅▅▄▅▅</td></tr><tr><td>loss</td><td>█▄▁▂▂▂▂▂▂▃▃▃▂▄▃▃▂▂▃▂▂▃▃▃▃▃▃▃▄▃▂▂▂▃▂▃▃▃▃▃</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>cost</td><td>0.02747</td></tr><tr><td>loss</td><td>0.02141</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 52 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">wandering-bee-48</strong>: <a href="https://wandb.ai/_devourer_/optimal-transport/runs/3m8uepei" target="_blank">https://wandb.ai/_devourer_/optimal-transport/runs/3m8uepei</a><br/>
# Find logs at: <code>./wandb/run-20220205_094547-3m8uepei/logs</code><br/>

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=SqGW_opt(2, 2, alpha=0., logger=wandb_logger),
    plotter=SimplePlotter(source_lims=None,
                    target_lims=None,
                    show_progress=False
                   ),
    logger=wandb_logger,
    # n_inner_iter=2,
)
# Out:
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/_devourer_/optimal-transport/runs/20512ds4" target="_blank">sweet-snow-49</a></strong> to <a href="https://wandb.ai/_devourer_/optimal-transport" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <br/>Waiting for W&B process to finish, PID 7353... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 5.22MB of 5.22MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>P MSE</td><td>█▂▁▃▁▂▃▃▃▂▃▂▄▃▄▃▃▄▄▃▃▃▄▃▃▃▃▃▄▃▃▃▃▃▃▃▄▃▂▄</td></tr><tr><td>cost</td><td>█▁▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▄▃▃▄▄▄▄▄▃▄</td></tr><tr><td>loss</td><td>█▁▂▂▁▂▂▂▃▃▃▃▃▃▃▄▃▃▃▃▃▃▃▄▄▃▃▄▃▃▄▃▄▄▄▄▄▄▄▄</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>P MSE</td><td>0.2282</td></tr><tr><td>cost</td><td>0.02013</td></tr><tr><td>loss</td><td>0.02914</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 51 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">sweet-snow-49</strong>: <a href="https://wandb.ai/_devourer_/optimal-transport/runs/20512ds4" target="_blank">https://wandb.ai/_devourer_/optimal-transport/runs/20512ds4</a><br/>
# Find logs at: <code>./wandb/run-20220205_095638-20512ds4/logs</code><br/>

# %% [markdown]
# ### sqGW

# %%
run_experiment(
    source, target,
    n_iter=5000,
    cost=SqGW(alpha=.0),
    plotter=SimplePlotter(source_lims=((-4, 4), (-4, 4)),
                    target_lims=((-4, 4), (-4, 4)),
                    show_progress=False),
    logger=wandb_logger
)
